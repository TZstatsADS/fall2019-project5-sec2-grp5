# %% [markdown]
# # Split train and test set

# %%
# #shuffle test and train images
# import random
# import os
# import shutil

# path_img = '/Users/rong/Documents/Columbia_python_jupyter_notebook/fall2019-proj5-sec2--proj5-grp5/data/train_set/images/'

# path_test_img = '/Users/rong/Documents/Columbia_python_jupyter_notebook/fall2019-proj5-sec2--proj5-grp5/data/train_set/test_images/'

# images = os.listdir(path_img)
# random.shuffle(images)
# test_set = images[-len(images)//5:]
# for image in test_set:

#     shutil.move(os.path.join(path_img, image), os.path.join(path_test_img, image))

# %% [markdown]
# # Packages

# %%
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys

# %% [markdown]
# # Data and Global variable

# %%
path_label = '/Users/rong/Documents/Columbia_python_jupyter_notebook/fall2019-proj5-sec2--proj5-grp5/data/train_set/label.csv'
path_img = '/Users/rong/Documents/Columbia_python_jupyter_notebook/fall2019-proj5-sec2--proj5-grp5/data/train_set/images/'
path_test_img = '/Users/rong/Documents/Columbia_python_jupyter_notebook/fall2019-proj5-sec2--proj5-grp5/data/train_set/test_images/'

# %%
label = pd.read_csv(path_label)

# %%
label
# Out:
#       Unnamed: 0  Index  identity  emotion_idx      emotion_cat      type
# 0              1      1       111            1          Neutral    simple
# 1              2      2       114            1          Neutral    simple
# 2              3      3       115            1          Neutral    simple
# 3              4      4       116            1          Neutral    simple
# 4              5      5       117            1          Neutral    simple
# 5              6      6       119            1          Neutral    simple
# 6              7      7       123            1          Neutral    simple
# 7              8      8       128            1          Neutral    simple
# 8              9      9       130            1          Neutral    simple
# 9             10     10       132            1          Neutral    simple
# 10            11     11       135            1          Neutral    simple
# 11            12     12       141            1          Neutral    simple
# 12            13     13       142            1          Neutral    simple
# 13            14     14       144            1          Neutral    simple
# 14            15     15       148            1          Neutral    simple
# 15            16     16       172            1          Neutral    simple
# 16            17     17       173            1          Neutral    simple
# 17            18     18       174            1          Neutral    simple
# 18            19     19       179            1          Neutral    simple
# 19            20     20       181            1          Neutral    simple
# 20            21     21       182            1          Neutral    simple
# 21            22     22       183            1          Neutral    simple
# 22            23     23       185            1          Neutral    simple
# 23            24     24       188            1          Neutral    simple
# 24            25     25       190            1          Neutral    simple
# 25            26     26       191            1          Neutral    simple
# 26            27     27       193            1          Neutral    simple
# 27            28     28       195            1          Neutral    simple
# 28            29     29       196            1          Neutral    simple
# 29            30     30       198            1          Neutral    simple
# ...          ...    ...       ...          ...              ...       ...
# 2470        2471   2471       337           22  Sadly disgusted  compound
# 2471        2472   2472       338           22  Sadly disgusted  compound
# 2472        2473   2473       339           22  Sadly disgusted  compound
# 2473        2474   2474       340           22  Sadly disgusted  compound
# 2474        2475   2475       341           22  Sadly disgusted  compound
# 2475        2476   2476       343           22  Sadly disgusted  compound
# 2476        2477   2477       345           22  Sadly disgusted  compound
# 2477        2478   2478       346           22  Sadly disgusted  compound
# 2478        2479   2479       348           22  Sadly disgusted  compound
# 2479        2480   2480       349           22  Sadly disgusted  compound
# 2480        2481   2481       351           22  Sadly disgusted  compound
# 2481        2482   2482       352           22  Sadly disgusted  compound
# 2482        2483   2483       353           22  Sadly disgusted  compound
# 2483        2484   2484       355           22  Sadly disgusted  compound
# 2484        2485   2485       361           22  Sadly disgusted  compound
# 2485        2486   2486       364           22  Sadly disgusted  compound
# 2486        2487   2487       365           22  Sadly disgusted  compound
# 2487        2488   2488       367           22  Sadly disgusted  compound
# 2488        2489   2489       368           22  Sadly disgusted  compound
# 2489        2490   2490       369           22  Sadly disgusted  compound
# 2490        2491   2491       370           22  Sadly disgusted  compound
# 2491        2492   2492       374           22  Sadly disgusted  compound
# 2492        2493   2493       377           22  Sadly disgusted  compound
# 2493        2494   2494       378           22  Sadly disgusted  compound
# 2494        2495   2495       381           22  Sadly disgusted  compound
# 2495        2496   2496       382           22  Sadly disgusted  compound
# 2496        2497   2497       386           22  Sadly disgusted  compound
# 2497        2498   2498       391           22  Sadly disgusted  compound
# 2498        2499   2499       392           22  Sadly disgusted  compound
# 2499        2500   2500       393           22  Sadly disgusted  compound
#
# [2500 rows x 6 columns]

# %%
set(label['emotion_cat'])
# Out:
# {'Angrily disgusted',
#  'Angrily surprised',
#  'Angry',
#  'Appalled',
#  'Awed',
#  'Disgusted',
#  'Disgustedly surprised',
#  'Fearful',
#  'Fearfully angry',
#  'Fearfully disgusted',
#  'Fearfully surprised',
#  'Happily disgusted',
#  'Happily surprised',
#  'Happy',
#  'Hatred',
#  'Neutral',
#  'Sad',
#  'Sadly angry',
#  'Sadly disgusted',
#  'Sadly fearful',
#  'Sadly surprised',
#  'Surprised'}

# %%
plt.hist(label[['emotion_cat']])

# %%
label[['emotion_cat']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-35b2378c8faf> in <module>
# ----> 1 label[['emotion_cat']].hist(bin = 22)
#
# /anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#    2406     fig, axes = _subplots(naxes=naxes, ax=ax, squeeze=False,
#    2407                           sharex=sharex, sharey=sharey, figsize=figsize,
# -> 2408                           layout=layout)
#    2409     _axes = _flatten(axes)
#    2410
#
# /anaconda3/lib/python3.7/site-packages/pandas/plotting/_tools.py in _subplots(naxes, sharex, sharey, squeeze, subplot_kw, ax, layout, layout_type, **fig_kw)
#     236
#     237     # Create first subplot separately, so we can share it if requested
# --> 238     ax0 = fig.add_subplot(nrows, ncols, 1, **subplot_kw)
#     239
#     240     if sharex:
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1365                     self._axstack.remove(ax)
#    1366
# -> 1367             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1368         self._axstack.add(key, a)
#    1369         self.sca(a)
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      58                     raise ValueError(
#      59                         ("num must be 1 <= num <= {maxn}, not {num}"
# ---> 60                         ).format(maxn=rows*cols, num=num))
#      61                 self._subplotspec = GridSpec(
#      62                         rows, cols, figure=self.figure)[int(num) - 1]
#
# ValueError: num must be 1 <= num <= 0, not 1
